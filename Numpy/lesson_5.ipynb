# %% [markdown]
# ## ways to change datatype

# %%
import numpy as np

# %%
a1=np.array([1,2,3,4,5],dtype=int)

# %%
print(a1)
# Out:
# [1 2 3 4 5]

# %%
a1.dtype
# Out:
# dtype('int64')

# %%
a2=a1.astype(float)

# %%
print(a2)
# Out:
# [1. 2. 3. 4. 5.]

# %%
print(a2.dtype)
# Out:
# float64
